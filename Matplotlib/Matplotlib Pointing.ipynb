# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([2, 2, 4, 4, 2])
ypoint = np.array([0, 3, 3, 0, 0])
matplotlib.pyplot.plot(xpoint, ypoint)
matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13876\274176940.py in <module>
#       4 xpoint = np.array([2, 2, 4, 4, 2])
#       5 ypoint = np.array([0, 3, 3, 0, 0])
# ----> 6 matplotlib.pyplot.plot(xpoint, ypoint)
#       7 matplotlib.pyplot.show()
#
# NameError: name 'matplotlib' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

xpoint = np.array([1, 1, 2, 3, 4, 4, 3, 2, 1])
ypoint = np.array([3, 4, 5, 5, 4, 3, 2, 2, 3])

plt.plot(xpoint, ypoint, "H--y", ms="20", mec="c", mfc="m")
plt.show()
